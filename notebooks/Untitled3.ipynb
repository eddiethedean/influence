# %%
import pandas as pd

# %%
df = pd.read_csv('../data/tcc_ceds_music.csv').drop('Unnamed: 0', axis=1)
df
# Out:
#                 artist_name                     track_name  release_date  \
# 0                    mukesh           mohabbat bhi jhoothi          1950
# 1             frankie laine                      i believe          1950
# 2               johnnie ray                            cry          1950
# 3               pérez prado                       patricia          1950
# 4      giorgos papadopoulos             apopse eida oneiro          1950
# ...                     ...                            ...           ...
# 28367               mack 10                10 million ways          2019
# 28368                m.o.p.  ante up (robbin hoodz theory)          2019
# 28369                  nine                  whutcha want?          2019
# 28370            will smith                         switch          2019
# 28371                 jeezy                         r.i.p.          2019
#
#          genre                                             lyrics  len  \
# ...

# %%
dists = pd.read_csv('../data/dists.csv')
dists
# Out:
#         y_index  x_index      score
# 0       17093.0     10.0   6.141335
# 1       17101.0     10.0   9.004950
# 2           5.0     10.0  15.026707
# 3           0.0     10.0  18.048463
# 4       17112.0     10.0  23.014760
# ...         ...      ...        ...
# 283205  12191.0  28371.0   0.523668
# 283206  22933.0  28371.0   0.538553
# 283207  27822.0  28371.0   0.539979
# 283208  27909.0  28371.0   0.545113
# 283209  22916.0  28371.0   0.557850
#
# [283210 rows x 3 columns]

# %%
def get_top_ten(df, dists, x_index):
    f = dists['x_index'] == x_index
    indexes = list(dists[f]['y_index'])
    return df.iloc[indexes]

# %%
get_top_ten(df, dists, 28370)
# Out:
#                             artist_name                    track_name  \
# 28196                          3rd bass                  the gas face
# 28185                         black rob              smile in ya face
# 28217                               nas                          hero
# 16574                       royal blood                 figure it out
# 27682                     royce da 5'9"  i'm fresh (feat. mr. porter)
# 27652                            j-kwon         tipsy 09 (radio edit)
# 28045                    big daddy kane                 'nuff respect
# 16670                          the arcs                       my mind
# 16968  black joe lewis & the honeybears             face in the scene
# 28251                      busta rhymes                 new york shit
#
#        release_date    genre  \
# 28196          2018  hip hop
# 28185          2018  hip hop
# 28217          2018  hip hop
# 16574          2014    blues
# 27682          2009  hip hop
# ...
